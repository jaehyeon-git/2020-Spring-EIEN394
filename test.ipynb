# %% [markdown]
# <a href="https://colab.research.google.com/github/jaehyeon-git/2020-Spring-EIEN394/blob/master/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
print(torch.tensor(1))
# Out:
# tensor(1)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import torch
import numpy
import matplotlib.pylab as plt
import matplotlib.image as mpimg

# %%
img1 = mpimg.imread("/content/gdrive/My Drive/2020-Spring-EIEN394/Images_L3/Image1.tif")

print('shape of image=', img1.shape, img1.dtype, type(img1))
# Out:
# shape of image= (571, 482) uint8 <class 'numpy.ndarray'>

# %%
plt.imshow(img1, cmap='gray')
plt.axis('off')
plt.colorbar()
plt.savefig('img1.jpg')
